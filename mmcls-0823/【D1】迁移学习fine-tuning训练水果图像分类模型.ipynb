# %% [markdown]
# # 迁移学习fine-tuning训练水果图像分类模型
#
# 在 MMClassification 模型库的预训练模型基础上，用自己的图像分类数据集，迁移学习，fine-tuning微调训练水果图像分类魔心。
#
# 同济子豪兄：https://space.bilibili.com/1900783
#
# [代码运行云GPU环境](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)：GPU RTX 3060、CUDA v11.2
#
# 2022-8-16

# %% [markdown]
# ## 进入 mmclassification 目录

# %%
import os
os.chdir('mmclassification')

# %% [markdown]
# ## 导入工具包

# %%
import torch
# 有 GPU 就用 GPU，没有就用 CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('device', device)
# Out:
# device cuda:0

# %% [markdown]
# ## 下载 config 配置文件

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/configs/mobilenet_v2_1x_fruit30.py -P configs/mobilenet_v2
# Out:
# --2022-08-22 23:23:52--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220716-mmclassification/configs/mobilenet_v2_1x_fruit30.py
# Connecting to 172.16.0.13:5848... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 1725 (1.7K) [binary/octet-stream]
# Saving to: ‘configs/mobilenet_v2/mobilenet_v2_1x_fruit30.py’
#
# mobilenet_v2_1x_fru 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2022-08-22 23:24:00 (28.0 MB/s) - ‘configs/mobilenet_v2/mobilenet_v2_1x_fruit30.py’ saved [1725/1725]

# %% [markdown]
# ## 研究 config 配置文件

# %% [markdown]
# ## 命令行-训练

# %%
# !python tools/train.py \
        configs/mobilenet_v2/mobilenet_v2_1x_fruit30.py \
        --work-dir work_dirs/mobilenet_v2_1x_fruit30
# Out:
# /home/featurize/work/MMClassification教程/mmclassification/mmcls/utils/setup_env.py:33: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   f'Setting OMP_NUM_THREADS environment variable for each process '
# /home/featurize/work/MMClassification教程/mmclassification/mmcls/utils/setup_env.py:43: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   f'Setting MKL_NUM_THREADS environment variable for each process '
# 2022-08-16 17:35:55,330 - mmcls - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
# CUDA available: True
# ...
