# %% [markdown]
# # 测试集总体准确率评估指标
#
# 分析测试集预测结果表格，计算总体准确率评估指标和各类别准确率评估指标。
# 同济子豪兄：https://space.bilibili.com/1900783
#
# [代码运行云GPU环境](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)：GPU RTX 3060、CUDA v11.2
#
# 2022-8-16

# %% [markdown]
# ## 进入 mmclassification 目录

# %%
import os
os.chdir('mmclassification')

# %% [markdown]
# ## 导入工具包

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 载入类别名称和ID

# %%
# 载入类别名称 和 ID索引号 的映射字典
idx_to_labels = np.load('idx_to_labels.npy', allow_pickle=True).item()
# 获得类别名称
classes = list(idx_to_labels.values())
print(classes)
# Out:
# ['哈密瓜', '圣女果', '山竹', '杨梅', '柚子', '柠檬', '桂圆', '梨', '椰子', '榴莲', '火龙果', '猕猴桃', '石榴', '砂糖橘', '胡萝卜', '脐橙', '芒果', '苦瓜', '苹果-红', '苹果-青', '草莓', '荔枝', '菠萝', '葡萄-白', '葡萄-红', '西瓜', '西红柿', '车厘子', '香蕉', '黄瓜']

# %% [markdown]
# ## 载入测试集预测结果表格

# %%
df = pd.read_csv('work_dirs/mobilenet_v2_1x_fruit30/测试集预测结果')

# %%
print(list(df['top-1-预测名称']))
# Out:
# ['哈密瓜', '椰子', '哈密瓜', '哈密瓜', '猕猴桃', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '胡萝卜', '哈密瓜', '哈密瓜', '芒果', '哈密瓜', '哈密瓜', '柚子', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '榴莲', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '哈密瓜', '圣女果', '圣女果', '圣女果', '圣女果', '西红柿', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '芒果', '西红柿', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '脐橙', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '圣女果', '西红柿', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '车厘子', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '山竹', '杨梅', '杨梅', '杨梅', '杨梅', '胡萝卜', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '石榴', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '草莓', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '杨梅', '车厘子', '杨梅', '柚子', '柠檬', '香蕉', '柚子', '柠檬', '猕猴桃', '柚子', '柚子', '柠檬', '柠檬', '柚子', '柚子', '柚子', '柚子', '柚子', '柚子', '柚子', '榴莲', '猕猴桃', '柚子', '柚子', '柠檬', '柠檬', '柚子', '柚子', '柚子', '柚子', '柠檬', '柚子', '柚子', '柚子', '柚子', '柚子', '苹果-青', '柚子', '柚子', '柚子', '柠檬', '柚子', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '黄瓜', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '柠檬', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '芒果', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '桂圆', '梨', '苹果-青', '梨', '梨', '梨', '梨', '梨', '梨', '梨', '梨', '梨', '梨', '葡萄-红', '苹果-青', '梨', '梨', '苹果-青', '梨', '梨', '梨', '苹果-青', '梨', '梨', '梨', '梨', '猕猴桃', '梨', '梨', '梨', '荔枝', '梨', '猕猴桃', '芒果', '梨', '梨', '梨', '梨', '椰子', '椰子', '苹果-青', '椰子', '椰子', '椰子', '椰子', '胡萝卜', '椰子', '椰子', '黄瓜', '椰子', '椰子', '椰子', '椰子', '椰子', '西瓜', '黄瓜', '椰子', '椰子', '椰子', '哈密瓜', '椰子', '椰子', '椰子', '椰子', '椰子', '椰子', '椰子', '椰子', '椰子', '葡萄-红', '椰子', '椰子', '椰子', '柠檬', '椰子', '椰子', '榴莲', '柠檬', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '榴莲', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '西瓜', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '胡萝卜', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '火龙果', '草莓', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '苹果-青', '脐橙', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '猕猴桃', '石榴', '石榴', '石榴', '苹果-红', '西瓜', '石榴', '石榴', '石榴', '草莓', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '石榴', '苹果-红', '石榴', '石榴', '山竹', '石榴', '圣女果', '荔枝', '石榴', '草莓', '石榴', '石榴', '石榴', '梨', '石榴', '砂糖橘', '砂糖橘', '脐橙', '砂糖橘', '砂糖橘', '砂糖橘', '脐橙', '脐橙', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '脐橙', '砂糖橘', '砂糖橘', '砂糖橘', '脐橙', '脐橙', '砂糖橘', '砂糖橘', '脐橙', '砂糖橘', '砂糖橘', '砂糖橘', '砂糖橘', '脐橙', '砂糖橘', '脐橙', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '桂圆', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '西瓜', '胡萝卜', '芒果', '黄瓜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '胡萝卜', '脐橙', '胡萝卜', '胡萝卜', '胡萝卜', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '猕猴桃', '脐橙', '脐橙', '脐橙', '脐橙', '柠檬', '柠檬', '哈密瓜', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '西瓜', '榴莲', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '脐橙', '梨', '柚子', '柠檬', '芒果', '芒果', '芒果', '芒果', '芒果', '芒果', '柠檬', '芒果', '柚子', '芒果', '柠檬', '芒果', '芒果', '芒果', '芒果', '芒果', '芒果', '黄瓜', '芒果', '芒果', '芒果', '芒果', '柚子', '榴莲', '芒果', '芒果', '芒果', '芒果', '芒果', '梨', '苦瓜', '黄瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜', '苦瓜 ...

# %% [markdown]
# ## 准确率

# %%
sum(df['标注类别名称'] == df['top-1-预测名称']) / len(df)
# Out:
# 0.04267161410018553

# %% [markdown]
# ## top-n准确率

# %%
sum(df['top-n预测正确']) / len(df)
# Out:
# 0.9629286376274329

# %% [markdown]
# ## 各类别准确率评估指标
#
# 公众号 人工智能小技巧 回复 混淆矩阵
#
# 看子豪兄视频和笔记讲解

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#          哈密瓜       0.91      0.79      0.85        38
#          圣女果       0.93      0.68      0.79        38
#           山竹       1.00      0.83      0.91        35
#           杨梅       0.86      0.86      0.86        37
#           柚子       0.76      0.76      0.76        37
#           柠檬       0.77      0.83      0.80        29
#           桂圆       0.76      1.00      0.86        38
#            梨       0.85      0.78      0.82        37
#           椰子       0.94      0.89      0.92        38
#           榴莲       0.94      0.81      0.87        36
#          火龙果       1.00      0.92      0.96        36
#          猕猴桃       0.97      0.86      0.91        37
#           石榴       0.87      0.89      0.88        37
#          砂糖橘       0.81      0.86      0.83        35
#          胡萝卜       0.94      0.89      0.91        36
#           脐橙       0.79      0.73      0.76        37
#           芒果       0.75      0.82      0.78        33
#           苦瓜       1.00      0.74      0.85        35
#         苹果-红       0.91      0.89      0.90        35
#         苹果-青       0.82      1.00      0.90        37
#           草莓       0.92      0.92      0.92        38
#           荔枝       0.88      0.92      0.90        38
#           菠萝       0.94      0.81      0.87        37
#         葡萄-白       0.94      0.94      0.94        31
#         葡萄-红       0.77      0.95      0.85        38
#           西瓜       0.85      0.95      0.90        37
#          西红柿       0.70      0.92      0.80        36
#          车厘子       1.00      0.84      0.92        32
#           香蕉       0.97      0.92      0.94        36
#           黄瓜       0.76      1.00      0.86        35
#
#     accuracy                           0.87      1079
#    macro avg       0.88      0.87      0.87      1079
# weighted avg       0.88      0.87      0.87      1079

# %% [markdown]
# maro avg 宏平均：直接将每一类的评估指标求和取平均（算数平均值）
#
# weighted avg 加权平均：按样本数量（support）加权计算评估指标的平均值

# %%
report = classification_report(df['标注类别名称'], df['top-1-预测名称'], target_names=classes, output_dict=True)
del report['accuracy']
df = pd.DataFrame(report).transpose()

# %%
df
# Out:
#               precision    recall  f1-score  support
# 哈密瓜            0.909091  0.789474  0.845070     38.0
# 圣女果            0.928571  0.684211  0.787879     38.0
# 山竹             1.000000  0.828571  0.906250     35.0
# 杨梅             0.864865  0.864865  0.864865     37.0
# 柚子             0.756757  0.756757  0.756757     37.0
# 柠檬             0.774194  0.827586  0.800000     29.0
# 桂圆             0.760000  1.000000  0.863636     38.0
# 梨              0.852941  0.783784  0.816901     37.0
# 椰子             0.944444  0.894737  0.918919     38.0
# 榴莲             0.935484  0.805556  0.865672     36.0
# 火龙果            1.000000  0.916667  0.956522     36.0
# 猕猴桃            0.969697  0.864865  0.914286     37.0
# 石榴             0.868421  0.891892  0.880000     37.0
# 砂糖橘            0.810811  0.857143  0.833333     35.0
# 胡萝卜            0.941176  0.888889  0.914286     36.0
# 脐橙             0.794118  0.729730  0.760563     37.0
# 芒果             0.750000  0.818182  0.782609     33.0
# 苦瓜             1.000000  0.742857  0.852459     35.0
# 苹果-红           0.911765  0.885714  0.898551     35.0
# 苹果-青           0.822222  1.000000  0.902439     37.0
# 草莓             0.921053  0.921053  0.921053     38.0
# 荔枝             0.875000  0.921053  0.897436     38.0
# 菠萝             0.937500  0.810811  0.869565     37.0
# 葡萄-白           0.935484  0.935484  0.935484     31.0
# 葡萄-红           0.765957  0.947368  0.847059     38.0
# 西瓜             0.853659  0.945946  0.897436     37.0
# 西红柿            0.702128  0.916667  0.795181     36.0
# 车厘子            1.000000  0.843750  0.915254     32.0
# 香蕉             0.970588  0.916667  0.942857     36.0
# 黄瓜             0.760870  1.000000  0.864198     35.0
# macro avg      0.877226  0.866343  0.866884   1079.0
# weighted avg   0.877204  0.866543  0.866931   1079.0

# %%
df.to_csv('各类别准确率评估指标.csv', index_label='类别')
